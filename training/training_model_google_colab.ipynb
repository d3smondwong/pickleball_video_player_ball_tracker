# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: roboflow in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (1.2.0)
# Requirement already satisfied: certifi in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2025.6.15)
# Requirement already satisfied: idna==3.7 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (3.10.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2.3.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pillow-heif<2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib->roboflow) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from requests->roboflow) (3.4.2)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ultralytics in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (8.3.161)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %% [markdown]
# ## Get Dataset

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="ftHhmXmYoorcuab83x0O")
project = rf.workspace('desmondwong').project("pickleball-vision-pabli")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: roboflow in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (1.2.0)
# Requirement already satisfied: certifi in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2025.6.15)
# Requirement already satisfied: idna==3.7 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (3.10.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2.3.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pillow-heif<2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib->roboflow) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\d3smo\anaconda3\envs\pb_analytics\lib\site-packages (from requests->roboflow) (3.4.2)
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## Use Google Colab to run this with GPU

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
